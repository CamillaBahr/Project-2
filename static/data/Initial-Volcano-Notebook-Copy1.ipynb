# %%
# Dependencies
import requests
import json
import pandas as pd

# %%
url = "cGVP-VOTW/wms?service=WFS&version=1.0.0&request=GetFeature&typeName=GVP-VOTW:E3WebApp_Eruptions1960&outputFormat=application%2Fjson"

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "crs": {
#         "properties": {
#             "name": "urn:ogc:def:crs:EPSG::4326"
#         },
#         "type": "name"
#     },
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     15.213,
#                     38.789
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2afc",
#             "properties": {
#                 "Activity_ID": 13435,
#                 "ContinuingEruption": "True",
#                 "EndDate": "20190210",
#                 "EndDateDay": 10,
#                 "EndDateMonth": 2,
#                 "EndDateYear": 2019,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 38.789,
#                 "LongitudeDecimal": 15.213,
#                 "StartDate": "19340202",
#                 "StartDateDay": 2,
#                 "StartDateMonth": 2,
#                 "StartDateYear": 1934,
#                 "VolcanoName": "Stromboli",
#                 "VolcanoNumber": 211040
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2afb",
#             "properties": {
#                 "Activity_ID": 13852,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20090704",
#                 "EndDateDay": 4,
#                 "EndDateMonth": 7,
#                 "EndDateYear": 2009,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20080513",
#                 "StartDateDay": 13,
#                 "StartDateMonth": 5,
#                 "StartDateYear": 2008,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2afa",
#             "properties": {
#                 "Activity_ID": 13853,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20100408",
#                 "EndDateDay": 8,
#                 "EndDateMonth": 4,
#                 "EndDateYear": 2010,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20100408",
#                 "StartDateDay": 8,
#                 "StartDateMonth": 4,
#                 "StartDateYear": 2010,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af9",
#             "properties": {
#                 "Activity_ID": 13854,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20130427",
#                 "EndDateDay": 27,
#                 "EndDateMonth": 4,
#                 "EndDateYear": 2013,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20100825",
#                 "StartDateDay": 25,
#                 "StartDateMonth": 8,
#                 "StartDateYear": 2010,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af8",
#             "properties": {
#                 "Activity_ID": 20841,
#                 "ContinuingEruption": "True",
#                 "EndDate": "20190213",
#                 "EndDateDay": 13,
#                 "EndDateMonth": 2,
#                 "EndDateYear": 2019,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20130903",
#                 "StartDateDay": 3,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 2013,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af7",
#             "properties": {
#                 "Activity_ID": 13837,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20031109",
#                 "EndDateDay": 9,
#                 "EndDateMonth": 11,
#                 "EndDateYear": 2003,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20030308",
#                 "StartDateDay": 8,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 2003,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af6",
#             "properties": {
#                 "Activity_ID": 13838,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20040214",
#                 "EndDateDay": 14,
#                 "EndDateMonth": 2,
#                 "EndDateYear": 2004,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20040212",
#                 "StartDateDay": 12,
#                 "StartDateMonth": 2,
#                 "StartDateYear": 2004,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af5",
#             "properties": {
#                 "Activity_ID": 13846,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20050308",
#                 "EndDateDay": 8,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 2005,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20040907",
#                 "StartDateDay": 7,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 2004,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af4",
#             "properties": {
#                 "Activity_ID": 13847,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20051222",
#                 "EndDateDay": 22,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 2005,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20051216",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 12,
#                 "StartDateYear": 2005,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af3",
#             "properties": {
#                 "Activity_ID": 13848,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20061215",
#                 "EndDateDay": 15,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 2006,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20060714",
#                 "StartDateDay": 14,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 2006,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af2",
#             "properties": {
#                 "Activity_ID": 13849,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20080516",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 5,
#                 "EndDateYear": 2008,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20070319",
#                 "StartDateDay": 19,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 2007,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af1",
#             "properties": {
#                 "Activity_ID": 13826,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19930203",
#                 "EndDateDay": 3,
#                 "EndDateMonth": 2,
#                 "EndDateYear": 1993,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19930203",
#                 "StartDateDay": 3,
#                 "StartDateMonth": 2,
#                 "StartDateYear": 1993,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2af0",
#             "properties": {
#                 "Activity_ID": 13827,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19931013",
#                 "EndDateDay": 13,
#                 "EndDateMonth": 10,
#                 "EndDateYear": 1993,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19930803",
#                 "StartDateDay": 3,
#                 "StartDateMonth": 8,
#                 "StartDateYear": 1993,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2aef",
#             "properties": {
#                 "Activity_ID": 13831,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20010717",
#                 "EndDateDay": 17,
#                 "EndDateMonth": 7,
#                 "EndDateYear": 2001,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19940617",
#                 "StartDateDay": 17,
#                 "StartDateMonth": 6,
#                 "StartDateYear": 1994,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2aee",
#             "properties": {
#                 "Activity_ID": 13832,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20010809",
#                 "EndDateDay": 9,
#                 "EndDateMonth": 8,
#                 "EndDateYear": 2001,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20010717",
#                 "StartDateDay": 17,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 2001,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2aed",
#             "properties": {
#                 "Activity_ID": 13835,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20021030",
#                 "EndDateDay": 30,
#                 "EndDateMonth": 10,
#                 "EndDateYear": 2002,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20011216",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 12,
#                 "StartDateYear": 2001,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2aec",
#             "properties": {
#                 "Activity_ID": 13836,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20030128",
#                 "EndDateDay": 28,
#                 "EndDateMonth": 1,
#                 "EndDateYear": 2003,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "20021026",
#                 "StartDateDay": 26,
#                 "StartDateMonth": 10,
#                 "StartDateYear": 2002,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2aeb",
#             "properties": {
#                 "Activity_ID": 13817,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19870301",
#                 "EndDateDay": 1,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1987,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19861030",
#                 "StartDateDay": 30,
#                 "StartDateMonth": 10,
#                 "StartDateYear": 1986,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2aea",
#             "properties": {
#                 "Activity_ID": 13818,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19870516",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 5,
#                 "EndDateYear": 1987,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19870308",
#                 "StartDateDay": 8,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 1987,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae9",
#             "properties": {
#                 "Activity_ID": 13819,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19890630",
#                 "EndDateDay": 30,
#                 "EndDateMonth": 6,
#                 "EndDateYear": 1989,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19881002",
#                 "StartDateDay": 2,
#                 "StartDateMonth": 10,
#                 "StartDateYear": 1988,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae8",
#             "properties": {
#                 "Activity_ID": 13820,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19891009",
#                 "EndDateDay": 9,
#                 "EndDateMonth": 10,
#                 "EndDateYear": 1989,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19890911",
#                 "StartDateDay": 11,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 1989,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae7",
#             "properties": {
#                 "Activity_ID": 13821,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19920523",
#                 "EndDateDay": 23,
#                 "EndDateMonth": 5,
#                 "EndDateYear": 1992,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19891216",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 12,
#                 "StartDateYear": 1989,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae6",
#             "properties": {
#                 "Activity_ID": 13825,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19930330",
#                 "EndDateDay": 30,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1993,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19911214",
#                 "StartDateDay": 14,
#                 "StartDateMonth": 12,
#                 "StartDateYear": 1991,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae5",
#             "properties": {
#                 "Activity_ID": 13811,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19830806",
#                 "EndDateDay": 6,
#                 "EndDateMonth": 8,
#                 "EndDateYear": 1983,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19830328",
#                 "StartDateDay": 28,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 1983,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae4",
#             "properties": {
#                 "Activity_ID": 13812,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19841018",
#                 "EndDateDay": 18,
#                 "EndDateMonth": 10,
#                 "EndDateYear": 1984,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19840428",
#                 "StartDateDay": 28,
#                 "StartDateMonth": 4,
#                 "StartDateYear": 1984,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae3",
#             "properties": {
#                 "Activity_ID": 13813,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19860924",
#                 "EndDateDay": 24,
#                 "EndDateMonth": 9,
#                 "EndDateYear": 1986,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19840720",
#                 "StartDateDay": 20,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 1984,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae2",
#             "properties": {
#                 "Activity_ID": 13814,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19850713",
#                 "EndDateDay": 13,
#                 "EndDateMonth": 7,
#                 "EndDateYear": 1985,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19850308",
#                 "StartDateDay": 8,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 1985,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae1",
#             "properties": {
#                 "Activity_ID": 13815,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19851231",
#                 "EndDateDay": 31,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 1985,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19851219",
#                 "StartDateDay": 19,
#                 "StartDateMonth": 12,
#                 "StartDateYear": 1985,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ae0",
#             "properties": {
#                 "Activity_ID": 13816,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19861031",
#                 "EndDateDay": 31,
#                 "EndDateMonth": 10,
#                 "EndDateYear": 1986,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19860316",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 1986,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2adf",
#             "properties": {
#                 "Activity_ID": 13805,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19921216",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 1992,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19790703",
#                 "StartDateDay": 3,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 1979,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ade",
#             "properties": {
#                 "Activity_ID": 13806,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19800901",
#                 "EndDateDay": 1,
#                 "EndDateMonth": 9,
#                 "EndDateYear": 1980,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19790716",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 1979,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2add",
#             "properties": {
#                 "Activity_ID": 13807,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19800926",
#                 "EndDateDay": 26,
#                 "EndDateMonth": 9,
#                 "EndDateYear": 1980,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19800708",
#                 "StartDateDay": 8,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 1980,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2adc",
#             "properties": {
#                 "Activity_ID": 13808,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19810305",
#                 "EndDateDay": 5,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1981,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19810126",
#                 "StartDateDay": 26,
#                 "StartDateMonth": 1,
#                 "StartDateYear": 1981,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2adb",
#             "properties": {
#                 "Activity_ID": 13809,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19810323",
#                 "EndDateDay": 23,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1981,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19810317",
#                 "StartDateDay": 17,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 1981,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ada",
#             "properties": {
#                 "Activity_ID": 13810,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19811126",
#                 "EndDateDay": 26,
#                 "EndDateMonth": 11,
#                 "EndDateYear": 1981,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19811126",
#                 "StartDateDay": 26,
#                 "StartDateMonth": 11,
#                 "StartDateYear": 1981,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad9",
#             "properties": {
#                 "Activity_ID": 13798,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19710612",
#                 "EndDateDay": 12,
#                 "EndDateMonth": 6,
#                 "EndDateYear": 1971,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19710405",
#                 "StartDateDay": 5,
#                 "StartDateMonth": 4,
#                 "StartDateYear": 1971,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad8",
#             "properties": {
#                 "Activity_ID": 13799,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19790316",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1979,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19710919",
#                 "StartDateDay": 19,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 1971,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad7",
#             "properties": {
#                 "Activity_ID": 13800,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19740329",
#                 "EndDateDay": 29,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1974,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19740130",
#                 "StartDateDay": 30,
#                 "StartDateMonth": 1,
#                 "StartDateYear": 1974,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad6",
#             "properties": {
#                 "Activity_ID": 13801,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19780329",
#                 "EndDateDay": 29,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1978,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19740929",
#                 "StartDateDay": 29,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 1974,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad5",
#             "properties": {
#                 "Activity_ID": 13803,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19750829",
#                 "EndDateDay": 29,
#                 "EndDateMonth": 8,
#                 "EndDateYear": 1975,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19750224",
#                 "StartDateDay": 24,
#                 "StartDateMonth": 2,
#                 "StartDateYear": 1975,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad4",
#             "properties": {
#                 "Activity_ID": 13804,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19781130",
#                 "EndDateDay": 30,
#                 "EndDateMonth": 11,
#                 "EndDateYear": 1978,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19780429",
#                 "StartDateDay": 29,
#                 "StartDateMonth": 4,
#                 "StartDateYear": 1978,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad3",
#             "properties": {
#                 "Activity_ID": 13795,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19641231",
#                 "EndDateDay": 31,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 1964,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19591017",
#                 "StartDateDay": 17,
#                 "StartDateMonth": 10,
#                 "StartDateYear": 1959,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad2",
#             "properties": {
#                 "Activity_ID": 13796,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19710316",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 1971,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19660110",
#                 "StartDateDay": 10,
#                 "StartDateMonth": 1,
#                 "StartDateYear": 1966,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     14.999,
#                     37.748
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad1",
#             "properties": {
#                 "Activity_ID": 13797,
#                 "ContinuingEruption": "False",
#                 "EndDate": "19680504",
#                 "EndDateDay": 4,
#                 "EndDateMonth": 5,
#                 "EndDateYear": 1968,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": 37.748,
#                 "LongitudeDecimal": 14.999,
#                 "StartDate": "19680107",
#                 "StartDateDay": 7,
#                 "StartDateMonth": 1,
#                 "StartDateYear": 1968,
#                 "VolcanoName": "Etna",
#                 "VolcanoNumber": 211060
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     41.83,
#                     15.55
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ad0",
#             "properties": {
#                 "Activity_ID": 13923,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20080616",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 6,
#                 "EndDateYear": 2008,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 15.55,
#                 "LongitudeDecimal": 41.83,
#                 "StartDate": "20070930",
#                 "StartDateDay": 30,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 2007,
#                 "VolcanoName": "Tair, Jebel at",
#                 "VolcanoNumber": 221010
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     42.18,
#                     15.05
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2acf",
#             "properties": {
#                 "Activity_ID": 20840,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20120112",
#                 "EndDateDay": 12,
#                 "EndDateMonth": 1,
#                 "EndDateYear": 2012,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 15.05,
#                 "LongitudeDecimal": 42.18,
#                 "StartDate": "20111218",
#                 "StartDateDay": 18,
#                 "StartDateMonth": 12,
#                 "StartDateYear": 2011,
#                 "VolcanoName": "Zubair Group",
#                 "VolcanoNumber": 221020
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     42.18,
#                     15.05
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2ace",
#             "properties": {
#                 "Activity_ID": 21068,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20131120",
#                 "EndDateDay": 20,
#                 "EndDateMonth": 11,
#                 "EndDateYear": 2013,
#                 "ExplosivityIndexMax": 2,
#                 "LatitudeDecimal": 15.05,
#                 "LongitudeDecimal": 42.18,
#                 "StartDate": "20130928",
#                 "StartDateDay": 28,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 2013,
#                 "VolcanoName": "Zubair Group",
#                 "VolcanoNumber": 221020
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     40.3,
#                     14.242
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2acd",
#             "properties": {
#                 "Activity_ID": 20939,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20110104",
#                 "EndDateDay": 4,
#                 "EndDateMonth": 1,
#                 "EndDateYear": 2011,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": 14.242,
#                 "LongitudeDecimal": 40.3,
#                 "StartDate": "20110104",
#                 "StartDateDay": 4,
#                 "StartDateMonth": 1,
#                 "StartDateYear": 2011,
#                 "VolcanoName": "Dallol",
#                 "VolcanoNumber": 221041
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     40.553,
#                     13.793
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-2acc",
#             "properties": {
#                 "Activity_ID": 13927,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20081216",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 2008,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 13.793,
# ...
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22f2",
#             "properties": {
#                 "Activity_ID": 20902,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20081025",
#                 "EndDateDay": 25,
#                 "EndDateMonth": 10,
#                 "EndDateYear": 2008,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20081025",
#                 "StartDateDay": 25,
#                 "StartDateMonth": 10,
#                 "StartDateYear": 2008,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22f1",
#             "properties": {
#                 "Activity_ID": 20903,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20121122",
#                 "EndDateDay": 22,
#                 "EndDateMonth": 11,
#                 "EndDateYear": 2012,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20120630",
#                 "StartDateDay": 30,
#                 "StartDateMonth": 6,
#                 "StartDateYear": 2012,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22f0",
#             "properties": {
#                 "Activity_ID": 21099,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20151008",
#                 "EndDateDay": 8,
#                 "EndDateMonth": 10,
#                 "EndDateYear": 2015,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20150828",
#                 "StartDateDay": 28,
#                 "StartDateMonth": 8,
#                 "StartDateYear": 2015,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22ef",
#             "properties": {
#                 "Activity_ID": 22271,
#                 "ContinuingEruption": "True",
#                 "EndDate": "20190101",
#                 "EndDateDay": 1,
#                 "EndDateMonth": 1,
#                 "EndDateYear": 2019,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20160928",
#                 "StartDateDay": 28,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 2016,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22ee",
#             "properties": {
#                 "Activity_ID": 13216,
#                 "ContinuingEruption": "False",
#                 "EndDate": null,
#                 "EndDateDay": null,
#                 "EndDateMonth": null,
#                 "EndDateYear": null,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "19961016",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 10,
#                 "StartDateYear": 1996,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22ed",
#             "properties": {
#                 "Activity_ID": 13217,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20011116",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 11,
#                 "EndDateYear": 2001,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20010916",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 9,
#                 "StartDateYear": 2001,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22ec",
#             "properties": {
#                 "Activity_ID": 13218,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20021116",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 11,
#                 "EndDateYear": 2002,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20020716",
#                 "StartDateDay": 16,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 2002,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22eb",
#             "properties": {
#                 "Activity_ID": 13219,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20030506",
#                 "EndDateDay": 6,
#                 "EndDateMonth": 5,
#                 "EndDateYear": 2003,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20030506",
#                 "StartDateDay": 6,
#                 "StartDateMonth": 5,
#                 "StartDateYear": 2003,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22ea",
#             "properties": {
#                 "Activity_ID": 13220,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20060120",
#                 "EndDateDay": 20,
#                 "EndDateMonth": 1,
#                 "EndDateYear": 2006,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20051002",
#                 "StartDateDay": 2,
#                 "StartDateMonth": 10,
#                 "StartDateYear": 2005,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -26.483,
#                     -57.8
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22e9",
#             "properties": {
#                 "Activity_ID": 13221,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20061206",
#                 "EndDateDay": 6,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 2006,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -57.8,
#                 "LongitudeDecimal": -26.483,
#                 "StartDate": "20060609",
#                 "StartDateDay": 9,
#                 "StartDateMonth": 6,
#                 "StartDateYear": 2006,
#                 "VolcanoName": "Saunders",
#                 "VolcanoNumber": 390090
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -27.57,
#                     -56.3
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22e8",
#             "properties": {
#                 "Activity_ID": 22159,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20160516",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 5,
#                 "EndDateYear": 2016,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": -56.3,
#                 "LongitudeDecimal": -27.57,
#                 "StartDate": "20160330",
#                 "StartDateDay": 30,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 2016,
#                 "VolcanoName": "Zavodovski",
#                 "VolcanoNumber": 390130
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -28.167,
#                     -55.912
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22e7",
#             "properties": {
#                 "Activity_ID": 13232,
#                 "ContinuingEruption": "False",
#                 "EndDate": null,
#                 "EndDateDay": null,
#                 "EndDateMonth": null,
#                 "EndDateYear": null,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -55.912,
#                 "LongitudeDecimal": -28.167,
#                 "StartDate": "19620305",
#                 "StartDateDay": 5,
#                 "StartDateMonth": 3,
#                 "StartDateYear": 1962,
#                 "VolcanoName": "Protector Seamounts",
#                 "VolcanoNumber": 390140
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.78,
#                     16.58
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22e6",
#             "properties": {
#                 "Activity_ID": 18529,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20100529",
#                 "EndDateDay": 29,
#                 "EndDateMonth": 5,
#                 "EndDateYear": 2010,
#                 "ExplosivityIndexMax": 3,
#                 "LatitudeDecimal": 16.58,
#                 "LongitudeDecimal": 145.78,
#                 "StartDate": "20100527",
#                 "StartDateDay": 27,
#                 "StartDateMonth": 5,
#                 "StartDateYear": 2010,
#                 "VolcanoName": "South Sarigan Seamount",
#                 "VolcanoNumber": 284193
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -5.22,
#                     -32.958
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22e5",
#             "properties": {
#                 "Activity_ID": 13144,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20020316",
#                 "EndDateDay": 16,
#                 "EndDateMonth": 3,
#                 "EndDateYear": 2002,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": -32.958,
#                 "LongitudeDecimal": -5.22,
#                 "StartDate": "20011124",
#                 "StartDateDay": 24,
#                 "StartDateMonth": 11,
#                 "StartDateYear": 2001,
#                 "VolcanoName": "Walvis Ridge at 33\u00b0S",
#                 "VolcanoNumber": 385052
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -179.033,
#                     -31.08
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22e4",
#             "properties": {
#                 "Activity_ID": 20748,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20120719",
#                 "EndDateDay": 19,
#                 "EndDateMonth": 7,
#                 "EndDateYear": 2012,
#                 "ExplosivityIndexMax": 1,
#                 "LatitudeDecimal": -31.08,
#                 "LongitudeDecimal": -179.033,
#                 "StartDate": "20120717",
#                 "StartDateDay": 17,
#                 "StartDateMonth": 7,
#                 "StartDateYear": 2012,
#                 "VolcanoName": "Havre Seamount",
#                 "VolcanoNumber": 242005
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.506,
#                     15.406
#                 ],
#                 "type": "Point"
#             },
#             "geometry_name": "GeoLocation",
#             "id": "E3WebApp_Eruptions1960.fid-76d3dfd_169cf732737_-22e3",
#             "properties": {
#                 "Activity_ID": 21102,
#                 "ContinuingEruption": "False",
#                 "EndDate": "20151201",
#                 "EndDateDay": 1,
#                 "EndDateMonth": 12,
#                 "EndDateYear": 2015,
#                 "ExplosivityIndexMax": 0,
#                 "LatitudeDecimal": 15.406,
#                 "LongitudeDecimal": 144.506,
#                 "StartDate": "20130213",
#                 "StartDateDay": 13,
#                 "StartDateMonth": 2,
#                 "StartDateYear": 2013,
#                 "VolcanoName": "Mariana Back-Arc Segment at 15.5\u00b0N",
#                 "VolcanoNumber": 284305
#             },
#             "type": "Feature"
#         }
#     ],
#     "totalFeatures": 2074,
#     "type": "FeatureCollection"
# }

# %%
features = []
lat = []
long = []
indexes = []
indexes = list(range(0,50))
name = []
active = []
explosive = []
startyear = []
startmonth = []



response = requests.get(url).json()
for index in indexes:
    lat.append(response['features'][index]['properties']['LatitudeDecimal'])
    long.append(response['features'][index]['properties']['LongitudeDecimal'])
    name.append(response['features'][index]['properties']['VolcanoName'])
    #active.append(response['features'[index]['properties']['ContinuingEruption']])
    explosive.append(response['features'][index]['properties']['ExplosivityIndexMax'])
    startyear.append(response['features'][index]['properties']['StartDateYear'])
    startmonth.append(response['features'][index]['properties']['StartDateMonth'])

# %%
volcano_dict = {
    "name": name,
    "lat": lat,
    "long": long,
    #"active": active,
    "explosive": explosive,
    "startyear": startyear,
    "startmonth": startmonth
}
volcano_data = pd.DataFrame(volcano_dict)
volcano_data
# Out:
#               name     lat    long  explosive  startyear  startmonth
# 0        Stromboli  38.789  15.213          2       1934           2
# 1             Etna  37.748  14.999          1       2008           5
# 2             Etna  37.748  14.999          2       2010           4
# 3             Etna  37.748  14.999          1       2010           8
# 4             Etna  37.748  14.999          2       2013           9
# 5             Etna  37.748  14.999          1       2003           3
# 6             Etna  37.748  14.999          1       2004           2
# 7             Etna  37.748  14.999          1       2004           9
# 8             Etna  37.748  14.999          1       2005          12
# 9             Etna  37.748  14.999          2       2006           7
# 10            Etna  37.748  14.999          2       2007           3
# 11            Etna  37.748  14.999          1       1993           2
# 12            Etna  37.748  14.999          1       1993           8
# 13            Etna  37.748  14.999          3       1994           6
# 14            Etna  37.748  14.999          2       2001           7
# 15            Etna  37.748  14.999          1       2001          12
# 16            Etna  37.748  14.999          3       2002          10
# 17            Etna  37.748  14.999          2       1986          10
# 18            Etna  37.748  14.999          2       1987           3
# 19            Etna  37.748  14.999          1       1988          10
# 20            Etna  37.748  14.999          2       1989           9
# 21            Etna  37.748  14.999          3       1989          12
# 22            Etna  37.748  14.999          2       1991          12
# 23            Etna  37.748  14.999          1       1983           3
# 24            Etna  37.748  14.999          1       1984           4
# 25            Etna  37.748  14.999          3       1984           7
# 26            Etna  37.748  14.999          1       1985           3
# 27            Etna  37.748  14.999          1       1985          12
# 28            Etna  37.748  14.999          2       1986           3
# 29            Etna  37.748  14.999          2       1979           7
# 30            Etna  37.748  14.999          3       1979           7
# 31            Etna  37.748  14.999          3       1980           7
# 32            Etna  37.748  14.999          2       1981           1
# 33            Etna  37.748  14.999          2       1981           3
# 34            Etna  37.748  14.999          2       1981          11
# 35            Etna  37.748  14.999          2       1971           4
# 36            Etna  37.748  14.999          2       1971           9
# 37            Etna  37.748  14.999          2       1974           1
# 38            Etna  37.748  14.999          2       1974           9
# 39            Etna  37.748  14.999          1       1975           2
# 40            Etna  37.748  14.999          2       1978           4
# 41            Etna  37.748  14.999          3       1959          10
# 42            Etna  37.748  14.999          2       1966           1
# 43            Etna  37.748  14.999          0       1968           1
# 44  Tair, Jebel at  15.550  41.830          3       2007           9
# 45    Zubair Group  15.050  42.180          2       2011          12
# 46    Zubair Group  15.050  42.180          2       2013           9
# 47          Dallol  14.242  40.300          0       2011           1
# 48   Alu-Dalafilla  13.793  40.553          3       2008          11
# 49        Erta Ale  13.600  40.670          0       1960           1
